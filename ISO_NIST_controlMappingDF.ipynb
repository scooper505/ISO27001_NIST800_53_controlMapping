# %%
import pandas as pd

# %%
csv_path = "resources/ISO_NIST_controlMapping_cleaned.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
ISO_NIST_controlMatrix_df = pd.read_csv(csv_path, sep=',')

# %%
ISO_NIST_controlMatrix_df
# Out:
#     ISO/IEC 27001 Controls                                         Unnamed: 1  \
# 0               Control ID                                      Control Title
# 1                      A.5                      Information Security Policies
# 2                    A.5.1      Management direction for information security
# 3                  A.5.1.1                  Policies for information security
# 4                  A.5.1.2    Review of the policies for information security
# 5                      A.6               Organization of information security
# 6                    A.6.1                              Internal organization
# 7                  A.6.1.1    Information security roles and responsibilities
# 8                  A.6.1.2                              Segregation of duties
# 9                  A.6.1.3                           Contact with authorities
# 10                 A.6.1.4               Contact with special interest groups
# ...
